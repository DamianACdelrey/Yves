# %% [markdown]
# #### First Notebook of the Course
#
# This is a simple notebook that tests the use of notebooks, using different types of cells along with some code and outputs.

# %%
import matplotlib.pyplot as plt

# %%
name = "Damián Álvarez Casal"
study_goal ="Learn data science"

study_hours = [2.0, 1.0, 1.5, 3.0]

print("student: ", name)
print("study goal: ", study_goal)

plt.plot(study_hours, marker='o')
plt.title('Horas de estudio')
plt.xlabel('Día')
plt.ylabel('Horas')
plt.xticks(range(len(study_hours)), range(1, len(study_hours) + 1))
plt.show()
# Out:
# student:  Damián Álvarez Casal
# study goal:  Learn data science
