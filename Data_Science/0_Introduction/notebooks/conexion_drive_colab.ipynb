# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ### Conexion de colab a google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/MyDrive/Yves"
# Out:
# notebooks

# %% [markdown]
# 2. Guardar el archivo del Notebook (.ipynb) en esa carpeta
#
# Colab, por defecto, siempre crea los notebooks nuevos en una carpeta llamada Colab Notebooks. No hay un botón de "Configuración" para cambiar esto globalmente, pero tienes dos alternativas:
#
# Desde el Notebook abierto: Ve al menú Archivo > Mover y selecciona tu carpeta de destino. Una vez movido, todos los cambios que hagas (Ctrl+S) se sincronizarán en esa ubicación.
